# %%
#Importing important libraries.
from bs4 import BeautifulSoup   # BS4 for Scrapping data from site.
import requests                 # Request to get the url
import pandas as pd 
# link contains Reviews only 
url = "https://www.urbancompany.com/reviews"  
s = requests.get(url)                         
soup = BeautifulSoup(s.content)  
com = soup.find("div", class_ = "ReviewCollectionParent__reviewActualPane--1dQI4")
names = []
dates = []
rates = []
comments = []

for i in range(11, 21): #Loop for multiple pages.
    
    urls = f"https://www.urbancompany.com/reviews?p={i}" 
    ct = requests.get(urls)
    soup = BeautifulSoup(ct.content)


    coms = soup.find_all("div", class_ ="ReviewPageReview__topInfo--3ibra")


    for com in coms:
        name = com.find("span", class_ = "ellipsis").text 
        date = com.find("span", class_ = "ReviewPageReview__reviewDate--3tC00").text    
        ratings = com.find("div", class_ = "StarRatingSEO__ratingBox--3MqzX StarRatingSEO__ratingBoxSmall--4Nhn8").text
        reviews = com.find("div", class_ = "ReviewPageReview__seoLinkDiv--2RnCy")
        if reviews is None:
            comments.append("None")
        else:
            comments.append(reviews.text)
            

        names.append(name)
        dates.append(date)
        rates.append(ratings)
print(len(names))
print(len(dates))
print(len(rates))
print(len(comments))
Services = []
Places = []

for i in comments:
    
    if i != "None":
        services,place=i.split(" in ")
        Services.append(services)
        Places.append(place)
        
    elif i == "None":
        Services.append("None")
        Places.append("None")
print(len(Services))
print(len(Places))

Country = []
City = []
for i in Places:
    
    if i == "None":
        City.append("None")
        Country.append("None")
        
    elif i != "None":
        city,country=i.split(", ")
        Country.append(country)
        City.append(city)

df = pd.DataFrame()
df["Dates"] = dates
df["Names"] = names
df["Ratings"] = rates
df["Services"] = Services
df["City"] = City
df["Counrty"] = Country
df["Comments"] = comments
df.to_excel("noclause.xlsx")
# Out:
# 80
# 80
# 80
# 80
# 80
# 80

# %%
df

# %%
#Importing important libraries.
from bs4 import BeautifulSoup   # BS4 for Scrapping data from site.
import requests                 # Request to get the url
import pandas as pd 
# link contains Reviews only 
url = "https://www.urbancompany.com/reviews"  
s = requests.get(url)                         
soup = BeautifulSoup(s.content)  
com = soup.find("div", class_ = "ReviewCollectionParent__reviewActualPane--1dQI4")
names = []
dates = []
rates = []
comments = []

for i in range(3000, 3100): #Loop for multiple pages.
    
    urls = f"https://www.urbancompany.com/reviews?p={i}" 
    ct = requests.get(urls)
    soup = BeautifulSoup(ct.content)


    coms = soup.find_all("div", class_ ="ReviewPageReview__topInfo--3ibra")


    for com in coms:
        name = com.find("span", class_ = "ellipsis").text 
        date = com.find("span", class_ = "ReviewPageReview__reviewDate--3tC00").text    
        ratings = com.find("div", class_ = "StarRatingSEO__ratingBox--3MqzX StarRatingSEO__ratingBoxSmall--4Nhn8").text
        reviews = com.find("div", class_ = "ReviewPageReview__seoLinkDiv--2RnCy")
        if reviews is None:
            comments.append("None")
        else:
            comments.append(reviews.text)
            

        names.append(name)
        dates.append(date)
        rates.append(ratings)
print(len(names))
print(len(dates))
print(len(rates))
print(len(comments))
Services = []
Places = []

for i in comments:
    
    if i != "None":
        services,place=i.split(" in ")
        Services.append(services)
        Places.append(place)
        
    elif i == "None":
        Services.append("None")
        Places.append("None")
print(len(Services))
print(len(Places))

Country = []
City = []
for i in Places:
    
    if i == "None":
        City.append("None")
        Country.append("None")
        
    elif i != "None":
        city,country=i.split(", ")
        Country.append(country)
        City.append(city)

df = pd.DataFrame()
df["Dates"] = dates
df["Names"] = names
df["Ratings"] = rates
df["Services"] = Services
df["City"] = City
df["Counrty"] = Country
df["Comments"] = comments
df.to_excel("output3000_3100.xlsx")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
df1=pd.read_excel('output3000_3100.xlsx')
df1
# Out:
#      Unnamed: 0           Dates                  Names  Ratings  \
# 0             0  30 March, 2022      Jayashree Chauhan      5.0
# 1             1  30 March, 2022    Rajalakshmi Sampath      5.0
# 2             2  30 March, 2022           Venkat Reddy      5.0
# 3             3  30 March, 2022                 Shilpa      5.0
# 4             4  30 March, 2022  Saurabh shingnapurkar      5.0
# ..          ...             ...                    ...      ...
# 995         995  30 March, 2022         Prashant Patil      5.0
# 996         996  30 March, 2022             Kathan rai      5.0
# 997         997  30 March, 2022       Ravindra Thakur       5.0
# 998         998  30 March, 2022       shubham sultania      5.0
# 999         999  30 March, 2022                 sameer      5.0
#
#                                               Services       City Counrty  \
# 0                                                 None       None    None
# 1                                                 None       None    None
# 2                  AC Service and Repair Professionals  Hyderabad   India
# 3                                                 None       None    None
# 4                  AC Service and Repair Professionals     Mumbai   India
# ..                                                 ...        ...     ...
# 995                AC Service and Repair Professionals     Mumbai   India
# 996                AC Service and Repair Professionals  Ahmedabad   India
# 997                                           Plumbers  Bangalore   India
# 998  RO and Water Purifier Repair Service Professio...  New Delhi   India
# 999                Fridge Repair Service Professionals  New Delhi   India
#
#                                               Comments
# 0                                                 None
# 1                                                 None
# 2    AC Service and Repair Professionals in Hyderab...
# 3                                                 None
# 4    AC Service and Repair Professionals in Mumbai,...
# ..                                                 ...
# 995  AC Service and Repair Professionals in Mumbai,...
# 996  AC Service and Repair Professionals in Ahmedab...
# 997                       Plumbers in Bangalore, India
# 998  RO and Water Purifier Repair Service Professio...
# 999  Fridge Repair Service Professionals in New Del...
#
# [1000 rows x 8 columns]

# %%
#Importing important libraries.
from bs4 import BeautifulSoup   # BS4 for Scrapping data from site.
import requests                 # Request to get the url
import pandas as pd 
# link contains Reviews only 
url = "https://www.urbancompany.com/reviews"  
s = requests.get(url)                         
soup = BeautifulSoup(s.content)  
com = soup.find("div", class_ = "ReviewCollectionParent__reviewActualPane--1dQI4")
names = []
dates = []
rates = []
comments = []

for i in range(3100, 4000): #Loop for multiple pages.
    
    urls = f"https://www.urbancompany.com/reviews?p={i}" 
    ct = requests.get(urls)
    soup = BeautifulSoup(ct.content)


    coms = soup.find_all("div", class_ ="ReviewPageReview__topInfo--3ibra")


    for com in coms:
        name = com.find("span", class_ = "ellipsis").text 
        date = com.find("span", class_ = "ReviewPageReview__reviewDate--3tC00").text    
        ratings = com.find("div", class_ = "StarRatingSEO__ratingBox--3MqzX StarRatingSEO__ratingBoxSmall--4Nhn8").text
        reviews = com.find("div", class_ = "ReviewPageReview__seoLinkDiv--2RnCy")
        if reviews is None:
            comments.append("None")
        else:
            comments.append(reviews.text)
            

        names.append(name)
        dates.append(date)
        rates.append(ratings)
print(len(names))
print(len(dates))
print(len(rates))
print(len(comments))
Services = []
Places = []

for i in comments:
    
    if i != "None":
        services,place=i.split(" in ")
        Services.append(services)
        Places.append(place)
        
    elif i == "None":
        Services.append("None")
        Places.append("None")
print(len(Services))
print(len(Places))

Country = []
City = []
for i in Places:
    
    if i == "None":
        City.append("None")
        Country.append("None")
        
    elif i != "None":
        city,country=i.split(", ")
        Country.append(country)
        City.append(city)

df = pd.DataFrame()
df["Dates"] = dates
df["Names"] = names
df["Ratings"] = rates
df["Services"] = Services
df["City"] = City
df["Counrty"] = Country
df["Comments"] = comments
df.to_excel("output3100_4000..xlsx")
# Out:
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000

# %%
df
# Out:
#                Dates             Names Ratings  \
# 0     30 March, 2022   Shalini Niddapu     5.0
# 1     30 March, 2022           Patrick     5.0
# 2     30 March, 2022  Ankur Srivastava     4.0
# 3     30 March, 2022        George Nag     5.0
# 4     30 March, 2022      Bhakti Doshi     5.0
# ...              ...               ...     ...
# 8995  30 March, 2022  swetha chelmilla     5.0
# 8996  30 March, 2022            Ayushi     5.0
# 8997  30 March, 2022     Nilesh Ranjan     5.0
# 8998  30 March, 2022        Sanjib Das     5.0
# 8999  30 March, 2022        Vikas Jain     5.0
#
#                                  Services       City Counrty  \
# 0                                    None       None    None
# 1                                    None       None    None
# 2                                    None       None    None
# 3                                    None       None    None
# 4            Beauty Service Professionals  Hyderabad   India
# ...                                   ...        ...     ...
# 8995                                 None       None    None
# 8996                                 None       None    None
# 8997  AC Service and Repair Professionals  Hyderabad   India
# 8998                                 None       None    None
# 8999                           Carpenters    Gurgaon   India
#
#                                                Comments
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4      Beauty Service Professionals in Hyderabad, India
# ...                                                 ...
# 8995                                               None
# 8996                                               None
# 8997  AC Service and Repair Professionals in Hyderab...
# 8998                                               None
# 8999                       Carpenters in Gurgaon, India
#
# [9000 rows x 7 columns]

# %%
df2=pd.read_excel('output3100_4000..xlsx')
df2
# Out:
#       Unnamed: 0           Dates             Names  Ratings  \
# 0              0  30 March, 2022   Shalini Niddapu      5.0
# 1              1  30 March, 2022           Patrick      5.0
# 2              2  30 March, 2022  Ankur Srivastava      4.0
# 3              3  30 March, 2022        George Nag      5.0
# 4              4  30 March, 2022      Bhakti Doshi      5.0
# ...          ...             ...               ...      ...
# 8995        8995  30 March, 2022  swetha chelmilla      5.0
# 8996        8996  30 March, 2022            Ayushi      5.0
# 8997        8997  30 March, 2022     Nilesh Ranjan      5.0
# 8998        8998  30 March, 2022        Sanjib Das      5.0
# 8999        8999  30 March, 2022        Vikas Jain      5.0
#
#                                  Services       City Counrty  \
# 0                                    None       None    None
# 1                                    None       None    None
# 2                                    None       None    None
# 3                                    None       None    None
# 4            Beauty Service Professionals  Hyderabad   India
# ...                                   ...        ...     ...
# 8995                                 None       None    None
# 8996                                 None       None    None
# 8997  AC Service and Repair Professionals  Hyderabad   India
# 8998                                 None       None    None
# 8999                           Carpenters    Gurgaon   India
#
#                                                Comments
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4      Beauty Service Professionals in Hyderabad, India
# ...                                                 ...
# 8995                                               None
# 8996                                               None
# 8997  AC Service and Repair Professionals in Hyderab...
# 8998                                               None
# 8999                       Carpenters in Gurgaon, India
#
# [9000 rows x 8 columns]

# %%
frames=[df1,df2]
df3=pd.concat(frames)
df3
# Out:
#       Unnamed: 0           Dates                  Names  Ratings  \
# 0              0  30 March, 2022      Jayashree Chauhan      5.0
# 1              1  30 March, 2022    Rajalakshmi Sampath      5.0
# 2              2  30 March, 2022           Venkat Reddy      5.0
# 3              3  30 March, 2022                 Shilpa      5.0
# 4              4  30 March, 2022  Saurabh shingnapurkar      5.0
# ...          ...             ...                    ...      ...
# 8995        8995  30 March, 2022       swetha chelmilla      5.0
# 8996        8996  30 March, 2022                 Ayushi      5.0
# 8997        8997  30 March, 2022          Nilesh Ranjan      5.0
# 8998        8998  30 March, 2022             Sanjib Das      5.0
# 8999        8999  30 March, 2022             Vikas Jain      5.0
#
#                                  Services       City Counrty  \
# 0                                    None       None    None
# 1                                    None       None    None
# 2     AC Service and Repair Professionals  Hyderabad   India
# 3                                    None       None    None
# 4     AC Service and Repair Professionals     Mumbai   India
# ...                                   ...        ...     ...
# 8995                                 None       None    None
# 8996                                 None       None    None
# 8997  AC Service and Repair Professionals  Hyderabad   India
# 8998                                 None       None    None
# 8999                           Carpenters    Gurgaon   India
#
#                                                Comments
# 0                                                  None
# 1                                                  None
# 2     AC Service and Repair Professionals in Hyderab...
# 3                                                  None
# 4     AC Service and Repair Professionals in Mumbai,...
# ...                                                 ...
# 8995                                               None
# 8996                                               None
# 8997  AC Service and Repair Professionals in Hyderab...
# 8998                                               None
# 8999                       Carpenters in Gurgaon, India
#
# [10000 rows x 8 columns]

# %%
df3.to_excel("output3000_4000..xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-7b9fc01bdf0c> in <module>
# ----> 1 df3.to_excel("output3000_4000..xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     829             # make sure to close opened file handles
#     830             if need_save:
# --> 831                 writer.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in close(self)
#     896     def close(self):
#     897         """synonym for save, to make it more file-like"""
# --> 898         content = self.save()
#     899         self.handles.close()
#     900         return content
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     196         Save workbook to disk.
#     197         """
# --> 198         return self.book.close()
#     199
#     200     def write_cells(
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319
#     320             try:
# --> 321                 self._store_workbook()
#     322             except IOError as e:
#     323                 raise FileCreateError(e)
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     706         packager._set_tmpdir(self.tmpdir)
#     707         packager._set_in_memory(self.in_memory)
# --> 708         xml_files = packager._create_package()
#     709
#     710         # Free up the Packager object.
#
# ~\anaconda3\lib\site-packages\xlsxwriter\packager.py in _create_package(self)
#     133         self._write_root_rels_file()
#     134         self._write_workbook_rels_file()
# --> 135         self._write_worksheet_files()
#     136         self._write_chartsheet_files()
#     137         self._write_workbook_file()
#
# ~\anaconda3\lib\site-packages\xlsxwriter\packager.py in _write_worksheet_files(self)
#     188             worksheet._set_xml_writer(self._filename('xl/worksheets/sheet'
#     189                                                      + str(index) + '.xml'))
# --> 190             worksheet._assemble_xml_file()
#     191             index += 1
#     192
#
# ~\anaconda3\lib\site-packages\xlsxwriter\worksheet.py in _assemble_xml_file(self)
#    3876         # Write the worksheet data such as rows columns and cells.
#    3877         if not self.constant_memory:
# -> 3878             self._write_sheet_data()
#    3879         else:
#    3880             self._write_optimized_sheet_data()
#
# ~\anaconda3\lib\site-packages\xlsxwriter\worksheet.py in _write_sheet_data(self)
#    5491         else:
#    5492             self._xml_start_tag('sheetData')
# -> 5493             self._write_rows()
#    5494             self._xml_end_tag('sheetData')
#    5495
#
# ~\anaconda3\lib\site-packages\xlsxwriter\worksheet.py in _write_rows(self)
#    5684                         if col_num in self.table[row_num]:
#    5685                             col_ref = self.table[row_num][col_num]
# -> 5686                             self._write_cell(row_num, col_num, col_ref)
#    5687
#    5688                     self._xml_end_tag('row')
#
# ~\anaconda3\lib\site-packages\xlsxwriter\worksheet.py in _write_cell(self, row, col, cell)
#    5847         attributes = [('r', cell_range)]
#    5848
# -> 5849         if cell.format:
#    5850             # Add the cell format index.
#    5851             xf_index = cell.format._get_xf_index()
#
# KeyboardInterrupt:

# %%
df=pd.read_excel('output3000_3100.xlsx')

# %%
df1=pd.read_excel('output30000_40000..xlsx')

# %%
df2=pd.read_excel('urban_company.xlsx')
df2
# Out:
#                     Dates              Names  Ratings  \
# 0          31 March, 2022      Riddham Desai      5.0
# 1          31 March, 2022   Abhinav Kushwaha      5.0
# 2          31 March, 2022        dola lahiri      5.0
# 3          31 March, 2022          Arunkumar      4.5
# 4          31 March, 2022              Divya      4.5
# ...                   ...                ...      ...
# 110937  27 February, 2022         Sri Harsha      5.0
# 110938  27 February, 2022           Srinivas      5.0
# 110939  27 February, 2022  Verified Customer      2.5
# 110940  27 February, 2022       Sweta Parekh      4.0
# 110941  27 February, 2022     Vandana Nishad      5.0
#
#                                                  Services           City  \
# 0                    Washing Machine Repair Professionals      Ahmedabad
# 1                                                    None           None
# 2                     Fridge Repair Service Professionals  Greater Noida
# 3                                                    None           None
# 4                    Washing Machine Repair Professionals  Greater Noida
# ...                                                   ...            ...
# 110937                                               None           None
# 110938  RO and Water Purifier Repair Service Professio...      Hyderabad
# 110939                                               None           None
# 110940                                               None           None
# 110941                                               None           None
#
#        Counrty                                           Comments
# 0        India  Washing Machine Repair Professionals in Ahmeda...
# 1         None                                               None
# 2        India  Fridge Repair Service Professionals in Greater...
# 3         None                                               None
# 4        India  Washing Machine Repair Professionals in Greate...
# ...        ...                                                ...
# 110937    None                                               None
# 110938   India  RO and Water Purifier Repair Service Professio...
# 110939    None                                               None
# 110940    None                                               None
# 110941    None                                               None
#
# [110942 rows x 7 columns]

# %%
frames=[df,df1,df2]
df4=pd.concat(frames)
df4
# Out:
#         Unnamed: 0              Dates                  Names  Ratings  \
# 0              0.0     30 March, 2022      Jayashree Chauhan      5.0
# 1              1.0     30 March, 2022    Rajalakshmi Sampath      5.0
# 2              2.0     30 March, 2022           Venkat Reddy      5.0
# 3              3.0     30 March, 2022                 Shilpa      5.0
# 4              4.0     30 March, 2022  Saurabh shingnapurkar      5.0
# ...            ...                ...                    ...      ...
# 110937         NaN  27 February, 2022             Sri Harsha      5.0
# 110938         NaN  27 February, 2022               Srinivas      5.0
# 110939         NaN  27 February, 2022      Verified Customer      2.5
# 110940         NaN  27 February, 2022           Sweta Parekh      4.0
# 110941         NaN  27 February, 2022         Vandana Nishad      5.0
#
#                                                  Services       City Counrty  \
# 0                                                    None       None    None
# 1                                                    None       None    None
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 3                                                    None       None    None
# 4                     AC Service and Repair Professionals     Mumbai   India
# ...                                                   ...        ...     ...
# 110937                                               None       None    None
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
# 110939                                               None       None    None
# 110940                                               None       None    None
# 110941                                               None       None    None
#
#                                                  Comments
# 0                                                    None
# 1                                                    None
# 2       AC Service and Repair Professionals in Hyderab...
# 3                                                    None
# 4       AC Service and Repair Professionals in Mumbai,...
# ...                                                   ...
# 110937                                               None
# 110938  RO and Water Purifier Repair Service Professio...
# 110939                                               None
# 110940                                               None
# 110941                                               None
#
# [211892 rows x 8 columns]

# %%
df4.to_excel("shama_final_output.xlsx")

# %%
df4=df4.drop(['Unnamed: 0'], axis=1)
df4
# Out:
#                     Dates                  Names  Ratings  \
# 0          30 March, 2022      Jayashree Chauhan      5.0
# 1          30 March, 2022    Rajalakshmi Sampath      5.0
# 2          30 March, 2022           Venkat Reddy      5.0
# 3          30 March, 2022                 Shilpa      5.0
# 4          30 March, 2022  Saurabh shingnapurkar      5.0
# ...                   ...                    ...      ...
# 110937  27 February, 2022             Sri Harsha      5.0
# 110938  27 February, 2022               Srinivas      5.0
# 110939  27 February, 2022      Verified Customer      2.5
# 110940  27 February, 2022           Sweta Parekh      4.0
# 110941  27 February, 2022         Vandana Nishad      5.0
#
#                                                  Services       City Counrty  \
# 0                                                    None       None    None
# 1                                                    None       None    None
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 3                                                    None       None    None
# 4                     AC Service and Repair Professionals     Mumbai   India
# ...                                                   ...        ...     ...
# 110937                                               None       None    None
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
# 110939                                               None       None    None
# 110940                                               None       None    None
# 110941                                               None       None    None
#
#                                                  Comments
# 0                                                    None
# 1                                                    None
# 2       AC Service and Repair Professionals in Hyderab...
# 3                                                    None
# 4       AC Service and Repair Professionals in Mumbai,...
# ...                                                   ...
# 110937                                               None
# 110938  RO and Water Purifier Repair Service Professio...
# 110939                                               None
# 110940                                               None
# 110941                                               None
#
# [211892 rows x 7 columns]

# %%
df4
# Out:
#                     Dates                  Names  Ratings  \
# 0          30 March, 2022      Jayashree Chauhan      5.0
# 1          30 March, 2022    Rajalakshmi Sampath      5.0
# 2          30 March, 2022           Venkat Reddy      5.0
# 3          30 March, 2022                 Shilpa      5.0
# 4          30 March, 2022  Saurabh shingnapurkar      5.0
# ...                   ...                    ...      ...
# 110937  27 February, 2022             Sri Harsha      5.0
# 110938  27 February, 2022               Srinivas      5.0
# 110939  27 February, 2022      Verified Customer      2.5
# 110940  27 February, 2022           Sweta Parekh      4.0
# 110941  27 February, 2022         Vandana Nishad      5.0
#
#                                                  Services       City Counrty  \
# 0                                                    None       None    None
# 1                                                    None       None    None
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 3                                                    None       None    None
# 4                     AC Service and Repair Professionals     Mumbai   India
# ...                                                   ...        ...     ...
# 110937                                               None       None    None
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
# 110939                                               None       None    None
# 110940                                               None       None    None
# 110941                                               None       None    None
#
#                                                  Comments
# 0                                                    None
# 1                                                    None
# 2       AC Service and Repair Professionals in Hyderab...
# 3                                                    None
# 4       AC Service and Repair Professionals in Mumbai,...
# ...                                                   ...
# 110937                                               None
# 110938  RO and Water Purifier Repair Service Professio...
# 110939                                               None
# 110940                                               None
# 110941                                               None
#
# [211892 rows x 7 columns]

# %%
df4.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)
df4
# Out:
#                     Dates                  Names  Ratings  \
# 0          30 March, 2022      Jayashree Chauhan      5.0
# 1          30 March, 2022    Rajalakshmi Sampath      5.0
# 2          30 March, 2022           Venkat Reddy      5.0
# 3          30 March, 2022                 Shilpa      5.0
# 4          30 March, 2022  Saurabh shingnapurkar      5.0
# ...                   ...                    ...      ...
# 110937  27 February, 2022             Sri Harsha      5.0
# 110938  27 February, 2022               Srinivas      5.0
# 110939  27 February, 2022      Verified Customer      2.5
# 110940  27 February, 2022           Sweta Parekh      4.0
# 110941  27 February, 2022         Vandana Nishad      5.0
#
#                                                  Services       City Counrty  \
# 0                                                    None       None    None
# 1                                                    None       None    None
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 3                                                    None       None    None
# 4                     AC Service and Repair Professionals     Mumbai   India
# ...                                                   ...        ...     ...
# 110937                                               None       None    None
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
# 110939                                               None       None    None
# 110940                                               None       None    None
# 110941                                               None       None    None
#
#                                                  Comments
# 0                                                    None
# 1                                                    None
# 2       AC Service and Repair Professionals in Hyderab...
# 3                                                    None
# 4       AC Service and Repair Professionals in Mumbai,...
# ...                                                   ...
# 110937                                               None
# 110938  RO and Water Purifier Repair Service Professio...
# 110939                                               None
# 110940                                               None
# 110941                                               None
#
# [178205 rows x 7 columns]

# %%
df4.replace('None',np.nan, inplace=True)

# %%
df4.dropna(inplace=True)

# %%
df4.shape
# Out:
# (105625, 7)

# %%
df4
# Out:
#                     Dates                  Names  Ratings  \
# 2          30 March, 2022           Venkat Reddy      5.0
# 4          30 March, 2022  Saurabh shingnapurkar      5.0
# 8          30 March, 2022          Purva  Mittal      5.0
# 9          30 March, 2022        Anand Dharavath      5.0
# 13         30 March, 2022           Neha Agarwal      4.5
# ...                   ...                    ...      ...
# 110933  27 February, 2022           Rakesh Patel      4.0
# 110934  27 February, 2022                sanjana      5.0
# 110935  27 February, 2022          sharanya bhat      5.0
# 110936  27 February, 2022            Manu Chawla      5.0
# 110938  27 February, 2022               Srinivas      5.0
#
#                                                  Services       City Counrty  \
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 4                     AC Service and Repair Professionals     Mumbai   India
# 8                            Beauty Service Professionals  Faridabad   India
# 9                                   Pest Control Services  Hyderabad   India
# 13                                           Electricians  Bangalore   India
# ...                                                   ...        ...     ...
# 110933               Washing Machine Repair Professionals       Pune   India
# 110934                       Beauty Service Professionals  Bangalore   India
# 110935  RO and Water Purifier Repair Service Professio...  Bangalore   India
# 110936                                           Plumbers  New Delhi   India
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
#
#                                                  Comments
# 2       AC Service and Repair Professionals in Hyderab...
# 4       AC Service and Repair Professionals in Mumbai,...
# 8        Beauty Service Professionals in Faridabad, India
# 9               Pest Control Services in Hyderabad, India
# 13                       Electricians in Bangalore, India
# ...                                                   ...
# 110933  Washing Machine Repair Professionals in Pune, ...
# 110934   Beauty Service Professionals in Bangalore, India
# 110935  RO and Water Purifier Repair Service Professio...
# 110936                       Plumbers in New Delhi, India
# 110938  RO and Water Purifier Repair Service Professio...
#
# [105625 rows x 7 columns]

# %%
df4["City"] = [city.translate(str.maketrans("", "", (string.punctuation + " "))) for city in df4["City"]]

# %%
df4["Dates"] = pd.to_datetime(df4["Dates"])
df4["Year"] = [date.year for date in df4["Dates"]]
df4["Month"] = [date.month for date in df4["Dates"]]
df4["Day"] = [date.day for date in df4["Dates"]]

df4 = df4.drop(columns = "Dates")

# %%
#visualization
sns.heatmap(df4.isnull())
# Out:
# <AxesSubplot:>

# %%
df4.columns
# Out:
# Index(['Names', 'Ratings', 'Services', 'City', 'Counrty', 'Comments', 'Year',
#        'Month', 'Day'],
#       dtype='object')

# %%
df4['Counrty'].value_counts()
# Out:
# India    104603
# Name: Counrty, dtype: int64

# %%
#dropping UAE from country
#df4.drop(df4[df4['Counrty']=='United Arab Emirates'],inplace=True)
df4 = df4[df4.Counrty != 'United Arab Emirates']
#df.drop(df.loc[df['line_race']==0].index, inplace=True)

# %%
df4.shape
# Out:
# (104603, 9)

# %%
df4
# Out:
#         Unnamed: 0              Dates                  Names  Ratings  \
# 0              0.0     30 March, 2022      Jayashree Chauhan      5.0
# 1              1.0     30 March, 2022    Rajalakshmi Sampath      5.0
# 2              2.0     30 March, 2022           Venkat Reddy      5.0
# 3              3.0     30 March, 2022                 Shilpa      5.0
# 4              4.0     30 March, 2022  Saurabh shingnapurkar      5.0
# ...            ...                ...                    ...      ...
# 110937         NaN  27 February, 2022             Sri Harsha      5.0
# 110938         NaN  27 February, 2022               Srinivas      5.0
# 110939         NaN  27 February, 2022      Verified Customer      2.5
# 110940         NaN  27 February, 2022           Sweta Parekh      4.0
# 110941         NaN  27 February, 2022         Vandana Nishad      5.0
#
#                                                  Services       City Counrty  \
# 0                                                    None       None    None
# 1                                                    None       None    None
# 2                     AC Service and Repair Professionals  Hyderabad   India
# 3                                                    None       None    None
# 4                     AC Service and Repair Professionals     Mumbai   India
# ...                                                   ...        ...     ...
# 110937                                               None       None    None
# 110938  RO and Water Purifier Repair Service Professio...  Hyderabad   India
# 110939                                               None       None    None
# 110940                                               None       None    None
# 110941                                               None       None    None
#
#                                                  Comments
# 0                                                    None
# 1                                                    None
# 2       AC Service and Repair Professionals in Hyderab...
# 3                                                    None
# 4       AC Service and Repair Professionals in Mumbai,...
# ...                                                   ...
# 110937                                               None
# 110938  RO and Water Purifier Repair Service Professio...
# 110939                                               None
# 110940                                               None
# 110941                                               None
#
# [211892 rows x 8 columns]

# %%
#Importing important libraries.
from bs4 import BeautifulSoup   # BS4 for Scrapping data from site.
import requests                 # Request to get the url
import pandas as pd 
# link contains Reviews only 
url = "https://www.urbancompany.com/reviews"  
s = requests.get(url)                         
soup = BeautifulSoup(s.content)  
com = soup.find("div", class_ = "ReviewCollectionParent__reviewActualPane--1dQI4")
names = []
dates = []
rates = []
comments = []

for i in range(30000, 40000): #Loop for multiple pages.
    
    urls = f"https://www.urbancompany.com/reviews?p={i}" 
    ct = requests.get(urls)
    soup = BeautifulSoup(ct.content)


    coms = soup.find_all("div", class_ ="ReviewPageReview__topInfo--3ibra")


    for com in coms:
        name = com.find("span", class_ = "ellipsis").text 
        date = com.find("span", class_ = "ReviewPageReview__reviewDate--3tC00").text    
        ratings = com.find("div", class_ = "StarRatingSEO__ratingBox--3MqzX StarRatingSEO__ratingBoxSmall--4Nhn8").text
        reviews = com.find("div", class_ = "ReviewPageReview__seoLinkDiv--2RnCy")
        if reviews is None:
            comments.append("None")
        else:
            comments.append(reviews.text)
            

        names.append(name)
        dates.append(date)
        rates.append(ratings)
print(len(names))
print(len(dates))
print(len(rates))
print(len(comments))
Services = []
Places = []

for i in comments:
    
    if i != "None":
        services,place=i.split(" in ")
        Services.append(services)
        Places.append(place)
        
    elif i == "None":
        Services.append("None")
        Places.append("None")
print(len(Services))
print(len(Places))

Country = []
City = []
for i in Places:
    
    if i == "None":
        City.append("None")
        Country.append("None")
        
    elif i != "None":
        city,country=i.split(", ")
        Country.append(country)
        City.append(city)

df = pd.DataFrame()
df["Dates"] = dates
df["Names"] = names
df["Ratings"] = rates
df["Services"] = Services
df["City"] = City
df["Counrty"] = Country
df["Comments"] = comments
df.to_excel("output30000_40000..xlsx")
# Out:
# 99950
# 99950
# 99950
# 99950
# 99950
# 99950

# %%
df
# Out:
#                 Dates              Names Ratings  \
# 0      26 March, 2022       Ganesh Dhuri     5.0
# 1      26 March, 2022         M S SHARMA     5.0
# 2      26 March, 2022  Verified Customer     5.0
# 3      26 March, 2022       Maliha Datta     5.0
# 4      26 March, 2022             Prasad     1.0
# ...               ...                ...     ...
# 99945  24 March, 2022  dhivya thangamani     4.5
# 99946  24 March, 2022              Ankur     5.0
# 99947  24 March, 2022          R G Desai     4.5
# 99948  24 March, 2022            Bhargav     5.0
# 99949  24 March, 2022            aravind     5.0
#
#                                   Services       City Counrty  \
# 0                               Carpenters     Mumbai   India
# 1                                     None       None    None
# 2                                     None       None    None
# 3                                     None       None    None
# 4                                 Plumbers     Mumbai   India
# ...                                    ...        ...     ...
# 99945                                 None       None    None
# 99946  AC Service and Repair Professionals     Mumbai   India
# 99947                                 None       None    None
# 99948                                 None       None    None
# 99949  AC Service and Repair Professionals  Hyderabad   India
#
#                                                 Comments
# 0                            Carpenters in Mumbai, India
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                              Plumbers in Mumbai, India
# ...                                                  ...
# 99945                                               None
# 99946  AC Service and Repair Professionals in Mumbai,...
# 99947                                               None
# 99948                                               None
# 99949  AC Service and Repair Professionals in Hyderab...
#
# [99950 rows x 7 columns]

# %%
# Let's import the required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re

from gensim import corpora
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from collections import Counter

import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('urban_company.xlsx')
df
# Out:
#                     Dates              Names  Ratings  \
# 0          31 March, 2022      Riddham Desai      5.0
# 1          31 March, 2022   Abhinav Kushwaha      5.0
# 2          31 March, 2022        dola lahiri      5.0
# 3          31 March, 2022          Arunkumar      4.5
# 4          31 March, 2022              Divya      4.5
# ...                   ...                ...      ...
# 110937  27 February, 2022         Sri Harsha      5.0
# 110938  27 February, 2022           Srinivas      5.0
# 110939  27 February, 2022  Verified Customer      2.5
# 110940  27 February, 2022       Sweta Parekh      4.0
# 110941  27 February, 2022     Vandana Nishad      5.0
#
#                                                  Services           City  \
# 0                    Washing Machine Repair Professionals      Ahmedabad
# 1                                                    None           None
# 2                     Fridge Repair Service Professionals  Greater Noida
# 3                                                    None           None
# 4                    Washing Machine Repair Professionals  Greater Noida
# ...                                                   ...            ...
# 110937                                               None           None
# 110938  RO and Water Purifier Repair Service Professio...      Hyderabad
# 110939                                               None           None
# 110940                                               None           None
# 110941                                               None           None
#
#        Counrty                                           Comments
# 0        India  Washing Machine Repair Professionals in Ahmeda...
# 1         None                                               None
# 2        India  Fridge Repair Service Professionals in Greater...
# 3         None                                               None
# 4        India  Washing Machine Repair Professionals in Greate...
# ...        ...                                                ...
# 110937    None                                               None
# 110938   India  RO and Water Purifier Repair Service Professio...
# 110939    None                                               None
# 110940    None                                               None
# 110941    None                                               None
#
# [110942 rows x 7 columns]

# %%
#checking NAN value
print("Contains NaN/Empty cells : ", df.isnull().values.any())
# Out:
# Contains NaN/Empty cells :  False

# %%
# Let's see how many Null Values are present in each column
print(df.isnull().sum())
# Out:
# Dates           0
# Names           0
# Ratings         0
# Services    49352
# City        49352
# Counrty     49352
# Comments    49352
# dtype: int64

# %%
df.replace('None',np.nan, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (61590, 7)
